# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('DatasetM.xlsx')
df1.head()
# Out:
#                     medName  medlife_price manufacturer  Ingredients  \
# 0           ABAMUNE 300 MG         1333.55   CIPLA LTD.     ABACAVIR
# 1                ABAMUNE L         2537.00   CIPLA LTD.     ABACAVIR
# 2  ACEFLEX PLUS 100/500 MG           15.99   CIPLA LTD.  ACECLOFENAC
# 3  ACEFLEX PLUS 100/500 MG           15.99   CIPLA LTD.  ACECLOFENAC
# 4             ACIGENE MINT            5.18   CIPLA LTD.          NaN
#
#   medicineType Pack Size       strength pack_form
# 0       TABLET        30         300 MG     Strip
# 1       TABLET        30  Not Available     Strip
# 2       TABLET        10     100/500 MG     Strip
# 3       TABLET        10     100/500 MG
# 4       TABLET        10  Not Available     Strip

# %%
df2 = pd.read_excel('DatasetO.xlsx')
df2.head()
# Out:
#                                         medName      manufacturer onemg_price  \
# 0                           Cofsils Cough Syrup  Cipla Health Ltd     â‚¹69.7
# 1             Nicogum 2 Mini Lozenges Mint Plus  Cipla Health Ltd     â‚¹76.5
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar Free  Cipla Health Ltd     â‚¹74.8
# 3                            Nicotex 21mg Patch  Cipla Health Ltd    â‚¹637.5
# 4   Nicotex 4mg Chewing Gums Classic Fresh Mint  Cipla Health Ltd     â‚¹74.8
#
#                                          Ingredients Prescription Required  \
# 0  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...                   Yes
# 1                                     Nicotine (2mg)                   Yes
# 2                                     Nicotine (4mg)                   Yes
# 3                                    Nicotine (21mg)                   Yes
# 4                                     Nicotine (4mg)                   Yes
#
# ...

# %%
df2['medicineType']= df2.medName.str.split('\s+').str[-1]

# %%
df2.head()
# Out:
#                                         medName      manufacturer onemg_price  \
# 0                           Cofsils Cough Syrup  Cipla Health Ltd     â‚¹69.7
# 1             Nicogum 2 Mini Lozenges Mint Plus  Cipla Health Ltd     â‚¹76.5
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar Free  Cipla Health Ltd     â‚¹74.8
# 3                            Nicotex 21mg Patch  Cipla Health Ltd    â‚¹637.5
# 4   Nicotex 4mg Chewing Gums Classic Fresh Mint  Cipla Health Ltd     â‚¹74.8
#
#                                          Ingredients Prescription Required  \
# 0  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...                   Yes
# 1                                     Nicotine (2mg)                   Yes
# 2                                     Nicotine (4mg)                   Yes
# 3                                    Nicotine (21mg)                   Yes
# 4                                     Nicotine (4mg)                   Yes
#
# ...

# %%
df2['medicin']= df2.medName.str.split('\s+').str[:-1]

# %%
df2.head()
# Out:
#                                         medName      manufacturer onemg_price  \
# 0                           Cofsils Cough Syrup  Cipla Health Ltd     â‚¹69.7
# 1             Nicogum 2 Mini Lozenges Mint Plus  Cipla Health Ltd     â‚¹76.5
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar Free  Cipla Health Ltd     â‚¹74.8
# 3                            Nicotex 21mg Patch  Cipla Health Ltd    â‚¹637.5
# 4   Nicotex 4mg Chewing Gums Classic Fresh Mint  Cipla Health Ltd     â‚¹74.8
#
#                                          Ingredients Prescription Required  \
# 0  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...                   Yes
# 1                                     Nicotine (2mg)                   Yes
# 2                                     Nicotine (4mg)                   Yes
# 3                                    Nicotine (21mg)                   Yes
# 4                                     Nicotine (4mg)                   Yes
#
# ...

# %%
df2['medicin']= df2.medicin.str.join(' ')
df2.head()
# Out:
#                                         medName      manufacturer onemg_price  \
# 0                           Cofsils Cough Syrup  Cipla Health Ltd     â‚¹69.7
# 1             Nicogum 2 Mini Lozenges Mint Plus  Cipla Health Ltd     â‚¹76.5
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar Free  Cipla Health Ltd     â‚¹74.8
# 3                            Nicotex 21mg Patch  Cipla Health Ltd    â‚¹637.5
# 4   Nicotex 4mg Chewing Gums Classic Fresh Mint  Cipla Health Ltd     â‚¹74.8
#
#                                          Ingredients Prescription Required  \
# 0  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...                   Yes
# 1                                     Nicotine (2mg)                   Yes
# 2                                     Nicotine (4mg)                   Yes
# 3                                    Nicotine (21mg)                   Yes
# 4                                     Nicotine (4mg)                   Yes
#
# ...

# %%
# df2 = df2.drop(['Med','medName'],axis = 1)
# df2.head()

# %%
cols = df2.columns.tolist()

# %%
cols
# Out:
# ['medName',
#  'manufacturer',
#  'onemg_price',
#  'Ingredients',
#  'Prescription Required',
#  'Units in Pack',
#  'Pack Size',
#  'Stock',
#  'Pack Form',
#  'Strength',
#  'medicineType',
#  'medicin']

# %%
cols = cols[-1:] + cols[:-1]

# %%
cols
# Out:
# ['medicin',
#  'medName',
#  'manufacturer',
#  'onemg_price',
#  'Ingredients',
#  'Prescription Required',
#  'Units in Pack',
#  'Pack Size',
#  'Stock',
#  'Pack Form',
#  'Strength',
#  'medicineType']

# %%
df2 = df2[cols]

# %%
df2.head()
# Out:
#                                    medicin  \
# 0                            Cofsils Cough
# 1             Nicogum 2 Mini Lozenges Mint
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar
# 3                             Nicotex 21mg
# 4   Nicotex 4mg Chewing Gums Classic Fresh
#
#                                         medName      manufacturer onemg_price  \
# 0                           Cofsils Cough Syrup  Cipla Health Ltd     â‚¹69.7
# 1             Nicogum 2 Mini Lozenges Mint Plus  Cipla Health Ltd     â‚¹76.5
# 2  Nicogum 4 Nicotine Gum Fresh Mint Sugar Free  Cipla Health Ltd     â‚¹74.8
# 3                            Nicotex 21mg Patch  Cipla Health Ltd    â‚¹637.5
# 4   Nicotex 4mg Chewing Gums Classic Fresh Mint  Cipla Health Ltd     â‚¹74.8
#
#                                          Ingredients Prescription Required  \
# 0  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...                   Yes
# 1                                     Nicotine (2mg)                   Yes
# ...

# %%
df2['medName'] = df2['medicin']
df2 = df2.drop(['medicin'],axis = 1)

# %%
cols = df2.columns.tolist()
cols = cols[-1:] + cols[:-1]
df2 = df2[cols]
df2.head()
# Out:
#   medicineType                                  medName      manufacturer  \
# 0        Syrup                            Cofsils Cough  Cipla Health Ltd
# 1         Plus             Nicogum 2 Mini Lozenges Mint  Cipla Health Ltd
# 2         Free  Nicogum 4 Nicotine Gum Fresh Mint Sugar  Cipla Health Ltd
# 3        Patch                             Nicotex 21mg  Cipla Health Ltd
# 4         Mint   Nicotex 4mg Chewing Gums Classic Fresh  Cipla Health Ltd
#
#   onemg_price                                        Ingredients  \
# 0     â‚¹69.7  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...
# 1     â‚¹76.5                                     Nicotine (2mg)
# 2     â‚¹74.8                                     Nicotine (4mg)
# 3    â‚¹637.5                                    Nicotine (21mg)
# 4     â‚¹74.8                                     Nicotine (4mg)
#
#   Prescription Required Units in Pack Pack Size Stock Pack Form       Strength
# ...

# %%
df2.medicineType.unique()
# Out:
# array(['Syrup', 'Plus', 'Free', 'Patch', 'Mint', 'Paan', 'Cinnamon',
#        'Gums', 'GEL', 'INHALER', 'TABLET', 'CAPSULE', 'Tablet',
#        'Infusion', 'Cream', 'Drop', 'Ointment', 'Injection', 'Gel', 'DT',
#        'Orange', 'Inhaler', 'Rotacap', 'ER', 'PR', 'Capsule',
#        'Expectorant', 'Kit', 'Solution', 'Respules', 'Rotacaps', 'Apple',
#        'Peppermint', 'Suspension', 'HFA', 'Cartridge', 'Kwikpen', 'hfa',
#        'aquanase', 'cream', 'Liquid', '2ml', 'ml', 'Aquanase', 'Spray',
#        'SR', 'Powder', 'DROP', 'INJECTION', 'INFUSION', 'OINTMENT',
#        'Rediuse', 'Mango', 'Vaccine', 'Wash', 'MR', 'Scrub', 'Drops',
#        'Yellow', 'VT', 'Lozenges', 'XL', 'SYRUP', 'Shampoo', 'DR',
#        'Combipack', '2.5ml', '3ml', 'Multihaler', 'GRANULES', 'MD', '4ml',
#        'Lemon', 'Foam', 'foam', 'Granules', 'SUSPENSION', 'MG',
#        'Strawberry', 'Autohaler', '200', '400', '0.5ml', 'currant',
# ...

# %%
df1.medicineType.unique()
# Out:
# array(['TABLET', 'INJECTION', 'GEL', 'GENERAL', 'SYRUP', 'CAPSULE',
#        'ROTACAP', 'RESPULES', 'ORAL SOLUTION', 'DRY SYRUP', 'POWDER',
#        'LIQUID', 'SOLUTION', 'CLEANSER'], dtype=object)

# %%
df2['medicineType'] = df2.medicineType.str.upper()

# %%
df2.medicineType.unique()
# Out:
# array(['SYRUP', 'PLUS', 'FREE', 'PATCH', 'MINT', 'PAAN', 'CINNAMON',
#        'GUMS', 'GEL', 'INHALER', 'TABLET', 'CAPSULE', 'INFUSION', 'CREAM',
#        'DROP', 'OINTMENT', 'INJECTION', 'DT', 'ORANGE', 'ROTACAP', 'ER',
#        'PR', 'EXPECTORANT', 'KIT', 'SOLUTION', 'RESPULES', 'ROTACAPS',
#        'APPLE', 'PEPPERMINT', 'SUSPENSION', 'HFA', 'CARTRIDGE', 'KWIKPEN',
#        'AQUANASE', 'LIQUID', '2ML', 'ML', 'SPRAY', 'SR', 'POWDER',
#        'REDIUSE', 'MANGO', 'VACCINE', 'WASH', 'MR', 'SCRUB', 'DROPS',
#        'YELLOW', 'VT', 'LOZENGES', 'XL', 'SHAMPOO', 'DR', 'COMBIPACK',
#        '2.5ML', '3ML', 'MULTIHALER', 'GRANULES', 'MD', '4ML', 'LEMON',
#        'FOAM', 'MG', 'STRAWBERRY', 'AUTOHALER', '200', '400', '0.5ML',
#        'CURRANT', 'LOTION', 'NATADROPS', 'XR', 'GUM', 'CAPLET', 'LACQUER',
#        'SYNCHROBREATHE', 'FRUIT', 'BANANA', 'BAR', 'DISKETTE', 'TR', 'CR',
#        'PESSARIES', 'SUPPOSITORY', 'SUSPENTION', 'OCTACAP', 'OCTACAPS',
# ...

# %%
df3 = df1
df4 = df2

# %%
med = ['TABLET', 'INJECTION', 'GEL', 'GENERAL', 'SYRUP', 'CAPSULE',
       'ROTACAP', 'RESPULES', 'ORAL SOLUTION', 'DRY SYRUP', 'POWDER',
       'LIQUID', 'SOLUTION', 'CLEANSER']

# %%
#  df4.drop(df4['df4.medicineType' not in med],inplace = True)
df4 = df4[df4.medicineType.isin(med)]
df4.head()
# Out:
#    medicineType                        medName      manufacturer  \
# 0         SYRUP                  Cofsils Cough  Cipla Health Ltd
# 17          GEL  ACIGENE 250MG/250MG/50MG ORAL         Cipla Ltd
# 19       TABLET                      ALERGIN L         Cipla Ltd
# 20      CAPSULE            ALIANZ 100 MG/20 MG         Cipla Ltd
# 21       TABLET          AMLOPRES-VL 5MG/160MG         Cipla Ltd
#
#       onemg_price                                        Ingredients  \
# 0         â‚¹69.7  Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...
# 17  Not Available  Aluminium Hydroxide (250mg) + Magnesium (250mg...
# 19  Not Available                               Levocetirizine (5mg)
# 20  Not Available            Diclofenac (100mg) + Rabeprazole (20mg)
# 21          â‚¹85               Amlodipine (5mg) + Valsartan (160mg)
#
#    Prescription Required  Units in Pack      Pack Size          Stock  \
# 0                    Yes              1            100            Yes
# ...

# %%
df4.medicineType.unique()
# Out:
# array(['SYRUP', 'GEL', 'TABLET', 'CAPSULE', 'INJECTION', 'ROTACAP',
#        'SOLUTION', 'RESPULES', 'LIQUID', 'POWDER'], dtype=object)

# %%
df3.head()
# Out:
#                     medName  medlife_price manufacturer  Ingredients  \
# 0           ABAMUNE 300 MG         1333.55   CIPLA LTD.     ABACAVIR
# 1                ABAMUNE L         2537.00   CIPLA LTD.     ABACAVIR
# 2  ACEFLEX PLUS 100/500 MG           15.99   CIPLA LTD.  ACECLOFENAC
# 3  ACEFLEX PLUS 100/500 MG           15.99   CIPLA LTD.  ACECLOFENAC
# 4             ACIGENE MINT            5.18   CIPLA LTD.          NaN
#
#   medicineType Pack Size       strength pack_form
# 0       TABLET        30         300 MG     Strip
# 1       TABLET        30  Not Available     Strip
# 2       TABLET        10     100/500 MG     Strip
# 3       TABLET        10     100/500 MG
# 4       TABLET        10  Not Available     Strip

# %%
df3 = df3.drop(['medlife_price','manufacturer','Pack Size','pack_form'],axis =1)
df3.head()
# Out:
#                     medName  Ingredients medicineType       strength
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available

# %%
df4 = df4.drop(['onemg_price','manufacturer','Pack Size','Pack Form','Units in Pack','Prescription Required'],axis = 1)

# %%
df4 = df4.drop(['Stock'],axis = 1)

# %%
df4.head()
# Out:
#    medicineType                        medName  \
# 0         SYRUP                  Cofsils Cough
# 17          GEL  ACIGENE 250MG/250MG/50MG ORAL
# 19       TABLET                      ALERGIN L
# 20      CAPSULE            ALIANZ 100 MG/20 MG
# 21       TABLET          AMLOPRES-VL 5MG/160MG
#
#                                           Ingredients       Strength
# 0   Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...  Not Available
# 17  Aluminium Hydroxide (250mg) + Magnesium (250mg...  Not Available
# 19                               Levocetirizine (5mg)  Not Available
# 20            Diclofenac (100mg) + Rabeprazole (20mg)  Not Available
# 21               Amlodipine (5mg) + Valsartan (160mg)  Not Available

# %%
df4 = df4[['medName','Ingredients','medicineType','Strength']]
df4.head()
# Out:
#                           medName  \
# 0                   Cofsils Cough
# 17  ACIGENE 250MG/250MG/50MG ORAL
# 19                      ALERGIN L
# 20            ALIANZ 100 MG/20 MG
# 21          AMLOPRES-VL 5MG/160MG
#
#                                           Ingredients medicineType  \
# 0   Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...        SYRUP
# 17  Aluminium Hydroxide (250mg) + Magnesium (250mg...          GEL
# 19                               Levocetirizine (5mg)       TABLET
# 20            Diclofenac (100mg) + Rabeprazole (20mg)      CAPSULE
# 21               Amlodipine (5mg) + Valsartan (160mg)       TABLET
#
#          Strength
# 0   Not Available
# 17  Not Available
# 19  Not Available
# 20  Not Available
# 21  Not Available

# %%
df3.rename(columns={'strength':'Strength'}, inplace=True)
df3.head(2)
# Out:
#            medName Ingredients medicineType       Strength
# 0  ABAMUNE 300 MG     ABACAVIR       TABLET         300 MG
# 1       ABAMUNE L     ABACAVIR       TABLET  Not Available

# %%
df4.head(2)
# Out:
#                           medName  \
# 0                   Cofsils Cough
# 17  ACIGENE 250MG/250MG/50MG ORAL
#
#                                           Ingredients medicineType  \
# 0   Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...        SYRUP
# 17  Aluminium Hydroxide (250mg) + Magnesium (250mg...          GEL
#
#          Strength
# 0   Not Available
# 17  Not Available

# %%
df4['medName'] = df4['medName'].str.upper()
df4.head(2)
# Out:
#                           medName  \
# 0                   COFSILS COUGH
# 17  ACIGENE 250MG/250MG/50MG ORAL
#
#                                           Ingredients medicineType  \
# 0   Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...        SYRUP
# 17  Aluminium Hydroxide (250mg) + Magnesium (250mg...          GEL
#
#          Strength
# 0   Not Available
# 17  Not Available

# %%
df4['Ingredients'] = df4['Ingredients'].str.upper()
df4.head()
# Out:
#                           medName  \
# 0                   COFSILS COUGH
# 17  ACIGENE 250MG/250MG/50MG ORAL
# 19                      ALERGIN L
# 20            ALIANZ 100 MG/20 MG
# 21          AMLOPRES-VL 5MG/160MG
#
#                                           Ingredients medicineType  \
# 0   DIPHENHYDRAMINE (14.08MG/5ML) + AMMONIUM CHLOR...        SYRUP
# 17  ALUMINIUM HYDROXIDE (250MG) + MAGNESIUM (250MG...          GEL
# 19                               LEVOCETIRIZINE (5MG)       TABLET
# 20            DICLOFENAC (100MG) + RABEPRAZOLE (20MG)      CAPSULE
# 21               AMLODIPINE (5MG) + VALSARTAN (160MG)       TABLET
#
#          Strength
# 0   Not Available
# 17  Not Available
# 19  Not Available
# 20  Not Available
# 21  Not Available

# %%
df4 = df4.reset_index(drop = True)
df4.head()
# Out:
#                          medName  \
# 0                  COFSILS COUGH
# 1  ACIGENE 250MG/250MG/50MG ORAL
# 2                      ALERGIN L
# 3            ALIANZ 100 MG/20 MG
# 4          AMLOPRES-VL 5MG/160MG
#
#                                          Ingredients medicineType  \
# 0  DIPHENHYDRAMINE (14.08MG/5ML) + AMMONIUM CHLOR...        SYRUP
# 1  ALUMINIUM HYDROXIDE (250MG) + MAGNESIUM (250MG...          GEL
# 2                               LEVOCETIRIZINE (5MG)       TABLET
# 3            DICLOFENAC (100MG) + RABEPRAZOLE (20MG)      CAPSULE
# 4               AMLODIPINE (5MG) + VALSARTAN (160MG)       TABLET
#
#         Strength
# 0  Not Available
# 1  Not Available
# 2  Not Available
# 3  Not Available
# 4  Not Available

# %%
df5=df3
df6=df4

# %%
df5.head()
# Out:
#                     medName  Ingredients medicineType       Strength
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available

# %%
df6.head()
# Out:
#                          medName  \
# 0                  COFSILS COUGH
# 1  ACIGENE 250MG/250MG/50MG ORAL
# 2                      ALERGIN L
# 3            ALIANZ 100 MG/20 MG
# 4          AMLOPRES-VL 5MG/160MG
#
#                                          Ingredients medicineType  \
# 0  DIPHENHYDRAMINE (14.08MG/5ML) + AMMONIUM CHLOR...        SYRUP
# 1  ALUMINIUM HYDROXIDE (250MG) + MAGNESIUM (250MG...          GEL
# 2                               LEVOCETIRIZINE (5MG)       TABLET
# 3            DICLOFENAC (100MG) + RABEPRAZOLE (20MG)      CAPSULE
# 4               AMLODIPINE (5MG) + VALSARTAN (160MG)       TABLET
#
#         Strength
# 0  Not Available
# 1  Not Available
# 2  Not Available
# 3  Not Available
# 4  Not Available

# %%
# df6[['Ingredients','Strength']] = df6.Ingredients.str.split('\(|\)', expand=True).iloc[:,[0,1]]
df6[['Ingredients','Strength']] = df6.Ingredients.str.split(' \(|\)', expand=True).iloc[:,[0,1]]

df6.head()
# Out:
#                          medName          Ingredients medicineType  \
# 0                  COFSILS COUGH      DIPHENHYDRAMINE        SYRUP
# 1  ACIGENE 250MG/250MG/50MG ORAL  ALUMINIUM HYDROXIDE          GEL
# 2                      ALERGIN L       LEVOCETIRIZINE       TABLET
# 3            ALIANZ 100 MG/20 MG           DICLOFENAC      CAPSULE
# 4          AMLOPRES-VL 5MG/160MG           AMLODIPINE       TABLET
#
#       Strength
# 0  14.08MG/5ML
# 1        250MG
# 2          5MG
# 3        100MG
# 4          5MG

# %%
df5.head()
# Out:
#                     medName  Ingredients medicineType       Strength
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available

# %%
df5.eq(df6).all(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3343    False
# 3344    False
# 3345    False
# 3346    False
# 3347    False
# Length: 3348, dtype: bool

# %%
df6[df5.eq(df6).all(axis=1)==False]
# Out:
#                             medName          Ingredients medicineType  \
# 0                     COFSILS COUGH      DIPHENHYDRAMINE        SYRUP
# 1     ACIGENE 250MG/250MG/50MG ORAL  ALUMINIUM HYDROXIDE          GEL
# 2                         ALERGIN L       LEVOCETIRIZINE       TABLET
# 3               ALIANZ 100 MG/20 MG           DICLOFENAC      CAPSULE
# 4             AMLOPRES-VL 5MG/160MG           AMLODIPINE       TABLET
# ...                             ...                  ...          ...
# 3343                    TROPAN XL 5           OXYBUTYNIN       TABLET
# 3344                 TROPEZ OD 60MG             TROSPIUM       TABLET
# 3345                      TYDOL 100           TAPENTADOL       TABLET
# 3346                       TYDOL 50           TAPENTADOL       TABLET
# 3347                  TYROGEF 250MG            GEFITINIB       TABLET
#
#          Strength
# 0     14.08MG/5ML
# 1           250MG
# 2             5MG
# 3           100MG
# 4             5MG
# ...

# %%
df7 = df5
df8 = df6

# %%
# df8[df7.eq(df8).all(axis=1)==False]

# %%
df7.head()
# Out:
#                     medName  Ingredients medicineType       Strength
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available

# %%
df8.head()
# Out:
#                          medName          Ingredients medicineType  \
# 0                  COFSILS COUGH      DIPHENHYDRAMINE        SYRUP
# 1  ACIGENE 250MG/250MG/50MG ORAL  ALUMINIUM HYDROXIDE          GEL
# 2                      ALERGIN L       LEVOCETIRIZINE       TABLET
# 3            ALIANZ 100 MG/20 MG           DICLOFENAC      CAPSULE
# 4          AMLOPRES-VL 5MG/160MG           AMLODIPINE       TABLET
#
#       Strength
# 0  14.08MG/5ML
# 1        250MG
# 2          5MG
# 3        100MG
# 4          5MG

# %%
# intersect = df2.Ingredients.isin(df1.Ingredients)

# %%
# def dataframe_difference(df7, df8, which=None):
#     """Find rows which are different between two DataFrames."""
#     comparison_df = df7.merge(df8,
#                               indicator=True,
#                               how='outer')
#     if which is None:
#         diff_df = comparison_df[comparison_df['_merge'] != 'both']
#     else:
#         diff_df = comparison_df[comparison_df['_merge'] == which]
#     diff_df.to_csv('intersection.csv')
#     return diff_df

# %%
# dataframe_difference(df7, df8, which='None')

# %%
df8['medicinename']= df8.medName.str.split('\s\d+').str[:-1]
df8.head()
# Out:
#                          medName          Ingredients medicineType  \
# 0                  COFSILS COUGH      DIPHENHYDRAMINE        SYRUP
# 1  ACIGENE 250MG/250MG/50MG ORAL  ALUMINIUM HYDROXIDE          GEL
# 2                      ALERGIN L       LEVOCETIRIZINE       TABLET
# 3            ALIANZ 100 MG/20 MG           DICLOFENAC      CAPSULE
# 4          AMLOPRES-VL 5MG/160MG           AMLODIPINE       TABLET
#
#       Strength   medicinename
# 0  14.08MG/5ML             []
# 1        250MG      [ACIGENE]
# 2          5MG             []
# 3        100MG       [ALIANZ]
# 4          5MG  [AMLOPRES-VL]

# %%
# df8['medicinename']= ''.join(str(e) for e in(df8.medicinename))

# %%
# df8['medicinename']= ''.join([str(elem) for elem in df8['medicinename']])
# df8.head()

# %%
df8['medicinename'] = df8['medicinename'].agg(lambda x: ''.join(map(str, x)))
df8.head()
# Out:
#                          medName          Ingredients medicineType  \
# 0                  COFSILS COUGH      DIPHENHYDRAMINE        SYRUP
# 1  ACIGENE 250MG/250MG/50MG ORAL  ALUMINIUM HYDROXIDE          GEL
# 2                      ALERGIN L       LEVOCETIRIZINE       TABLET
# 3            ALIANZ 100 MG/20 MG           DICLOFENAC      CAPSULE
# 4          AMLOPRES-VL 5MG/160MG           AMLODIPINE       TABLET
#
#       Strength medicinename
# 0  14.08MG/5ML
# 1        250MG      ACIGENE
# 2          5MG
# 3        100MG       ALIANZ
# 4          5MG  AMLOPRES-VL

# %%
df7['medicinename']= df7.medName.str.split('\s\d+').str[:-1]
df7.head()
# Out:
#                     medName  Ingredients medicineType       Strength  \
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available
#
#      medicinename
# 0       [ABAMUNE]
# 1              []
# 2  [ACEFLEX PLUS]
# 3  [ACEFLEX PLUS]
# 4              []

# %%
df7['medicinename'] = df7['medicinename'].agg(lambda x: ''.join(map(str, x)))
df7.head()
# Out:
#                     medName  Ingredients medicineType       Strength  \
# 0           ABAMUNE 300 MG      ABACAVIR       TABLET         300 MG
# 1                ABAMUNE L      ABACAVIR       TABLET  Not Available
# 2  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 3  ACEFLEX PLUS 100/500 MG   ACECLOFENAC       TABLET     100/500 MG
# 4             ACIGENE MINT           NaN       TABLET  Not Available
#
#    medicinename
# 0       ABAMUNE
# 1
# 2  ACEFLEX PLUS
# 3  ACEFLEX PLUS
# 4

# %%
# df8[df7.eq(df8).all(axis=1)==False]

# %%
 matchname = set(df7['medicinename']).intersection(set(df8['medicinename']))

# %%
matchname
# Out:
# {'',
#  'AB PHYLLINE SR',
#  'ACEFLEX PLUS',
#  'ACIVIR',
#  'ACMIL',
#  'ACTIFLU',
#  'ACTORISE',
#  'ADESAM',
#  'ADFOVIR',
#  'ADMENTA',
#  'ADVENT',
#  'AGODEP',
#  'AMANAT',
#  'AMIVAL',
#  'AMLIP',
#  'AMLOPRES',
#  'AMLOPRES AT',
#  'AMLOSUN',
#  'AMPREZ',
#  'ANDROBLOK',
#  'ANGIZEM DP',
#  'AQSUSTEN',
#  'AQUAZIDE',
#  'ARPIZOL',
#  'ASPIN',
#  'ASTHALIN',
#  'ASTHALIN SA',
#  'ATORLIP',
#  'ATORLIP CV',
#  'ATTENTROL',
#  'AXCER',
#  'AZAX',
#  'AZEE',
#  'AZICIP',
#  'AZIMAX',
#  'AZIPRO',
#  'AZTOGOLD',
#  'AZTOLET',
#  'AZTOR',
#  'AZTOR ASP',
#  'AZTOR EZ',
#  'BAMBUDIL',
#  'BECLATE',
#  'BENDEX',
#  'BESTOCEF',
#  'BETACAP',
#  'BETACAP TR',
#  'BETAVERT',
#  'BETAVERT OD',
#  'BILASURE',
#  'BOSENTAS',
#  'BROMEX',
#  'BUDECORT',
#  'BUPRON SR',
#  'BUPRON XL',
#  'CABERLIN',
#  'CABGOLIN',
#  'CALUTIDE',
#  'CAPEGARD',
#  'CARDIVAS',
#  'CARDIVAS CR',
#  'CARLOC',
#  'CEFASYN',
#  'CEFBACT',
#  'CEFBACT S',
#  'CEFIX',
#  'CEFOPROX',
#  'CEFOPROX CV',
# ...

# %%
match = df8.medicinename.isin(df7.medicinename)

# %%
match
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 3343     True
# 3344    False
# 3345    False
# 3346    False
# 3347    False
# Name: medicinename, Length: 3348, dtype: bool

# %%
df9 = df7
df10 = df8

# %%
df9 = df9.drop(['medName'],axis = 1)
df10 = df10.drop(['medName'],axis = 1)

# %%
intersected_df = pd.merge(df9, df10, how='inner')
print(intersected_df)
# Out:
# Empty DataFrame
# Columns: [Ingredients, medicineType, Strength, medicinename]
# Index: []

# %%
# df7['Strength'] = df7['Strength'].agg(lambda x: ' '.join(map(str, x)))
df9['Strength'] = df9['Strength'].str.replace(' ', '')

# df9['Strength'] = ' '.join(df9['Strength'])
df9.head()
# Out:
#    Ingredients medicineType      Strength  medicinename
# 0     ABACAVIR       TABLET         300MG       ABAMUNE
# 1     ABACAVIR       TABLET  NotAvailable
# 2  ACECLOFENAC       TABLET     100/500MG  ACEFLEX PLUS
# 3  ACECLOFENAC       TABLET     100/500MG  ACEFLEX PLUS
# 4          NaN       TABLET  NotAvailable

# %%
df10.head()
# Out:
#            Ingredients medicineType     Strength medicinename
# 0      DIPHENHYDRAMINE        SYRUP  14.08MG/5ML
# 1  ALUMINIUM HYDROXIDE          GEL        250MG      ACIGENE
# 2       LEVOCETIRIZINE       TABLET          5MG
# 3           DICLOFENAC      CAPSULE        100MG       ALIANZ
# 4           AMLODIPINE       TABLET          5MG  AMLOPRES-VL

# %%
 set(df10['Ingredients']).intersection(set(df9['Ingredients']))
# Out:
# {'ABACAVIR',
#  'ACAMPROSATE',
#  'ACEBROPHYLLINE',
#  'ACECLOFENAC',
#  'ACETYLCYSTEINE',
#  'ACOTIAMIDE',
#  'ACYCLOVIR',
#  'ADAPALENE',
#  'ADEFOVIR',
#  'AGOMELATINE',
#  'ALBENDAZOLE',
#  'ALLOPURINOL',
#  'AMANTADINE',
#  'AMBRISENTAN',
#  'AMBROXOL',
#  'AMIKACIN',
#  'AMIODARONE',
#  'AMISULPRIDE',
#  'AMLODIPINE',
#  'AMPICILLIN',
#  'ANASTROZOLE',
#  'APREMILAST',
#  'ARIPIPRAZOLE',
#  'ARTEMETHER',
#  'ATAZANAVIR',
#  'ATENOLOL',
#  'ATOMOXETINE',
#  'ATORVASTATIN',
#  'AZITHROMYCIN',
#  'BACLOFEN',
#  'BAMBUTEROL',
#  'BECLOMETASONE',
#  'BENDAMUSTINE',
#  'BETAHISTINE',
#  'BETAMETHASONE',
#  'BETHANECHOL',
#  'BICALUTAMIDE',
#  'BILASTINE',
#  'BOSENTAN',
#  'BROMHEXINE',
#  'BUDESONIDE',
#  'BUPROPION',
#  'CABERGOLINE',
#  'CAFFEINE',
#  'CANAGLIFLOZIN',
#  'CAPECITABINE',
#  'CARBAMAZEPINE',
#  'CARVEDILOL',
#  'CEFALEXIN',
#  'CEFIXIME',
#  'CEFTRIAXONE',
#  'CEFUROXIME',
#  'CELECOXIB',
#  'CETIRIZINE',
#  'CETRORELIX',
#  'CHLORZOXAZONE',
#  'CILNIDIPINE',
# ...

# %%
#  set(df10['Strength']).intersection(set(df9['Strength']))

# %%
#  df10.medicinename.isin(df9.medicinename) & df10.Ingredients.isin(df9.Ingredients)
intersected_df = pd.merge(df9, df10, how='inner')

print(intersected_df[:50])
# Out:
#      Ingredients medicineType Strength medicinename
# 0     AMLODIPINE       TABLET     10MG        AMLIP
# 1     AMLODIPINE       TABLET    2.5MG        AMLIP
# 2     AMLODIPINE       TABLET      5MG        AMLIP
# 3     AMLODIPINE       TABLET     10MG     AMLOPRES
# 4     AMLODIPINE       TABLET    2.5MG     AMLOPRES
# 5     AMLODIPINE       TABLET      5MG     AMLOPRES
# 6     AMLODIPINE       TABLET      5MG     AMLOPRES
# 7     AMLODIPINE       TABLET      5MG     AMLOPRES
# 8     AMLODIPINE       TABLET      5MG     AMLOPRES
# 9   ATORVASTATIN       TABLET     10MG      ATORLIP
# 10  ATORVASTATIN       TABLET     10MG      ATORLIP
# 11  ATORVASTATIN       TABLET     10MG      ATORLIP
# 12  ATORVASTATIN       TABLET     10MG      ATORLIP
# 13  ATORVASTATIN       TABLET     20MG      ATORLIP
# 14  ATORVASTATIN       TABLET     20MG      ATORLIP
# 15  ATORVASTATIN       TABLET     20MG      ATORLIP
# 16  ATORVASTATIN       TABLET     20MG      ATORLIP
# ...

# %%
df9.medicinename
# Out:
# Ingredients      7
# medicineType     0
# Strength        16
# medicinename     0
# dtype: int64

# %%
intersected_df = intersected_df.drop_duplicates(keep=False) 
print(intersected_df[:50])
# Out:
#           Ingredients medicineType Strength medicinename
# 0          AMLODIPINE       TABLET     10MG        AMLIP
# 1          AMLODIPINE       TABLET    2.5MG        AMLIP
# 2          AMLODIPINE       TABLET      5MG        AMLIP
# 3          AMLODIPINE       TABLET     10MG     AMLOPRES
# 4          AMLODIPINE       TABLET    2.5MG     AMLOPRES
# 21       ATORVASTATIN       TABLET     80MG      ATORLIP
# 22       ATORVASTATIN      CAPSULE     20MG   ATORLIP CV
# 23       AZITHROMYCIN       TABLET   1000MG         AZEE
# 44       AZITHROMYCIN       TABLET    250MG       AZIPRO
# 45       AZITHROMYCIN       TABLET    500MG       AZIPRO
# 46         BAMBUTEROL       TABLET     10MG     BAMBUDIL
# 47        ALBENDAZOLE       TABLET    400MG       BENDEX
# 48           BOSENTAN       TABLET    125MG     BOSENTAS
# 49           BOSENTAN       TABLET   62.5MG     BOSENTAS
# 50       BICALUTAMIDE       TABLET     50MG     CALUTIDE
# ...

# %%
intersected_df.to_excel ('exportmatch_dataframe.xlsx', index = False, header=True)
